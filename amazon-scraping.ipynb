# %% [markdown]
# # Amazon Web Scraper: Product Search

# %%
import csv # csv file reading and writing
from bs4 import BeautifulSoup # web scraping
from selenium import webdriver # web browser automation
import numpy as np
import pandas as pd

# %% [markdown]
# ## Building the functions

# %% [markdown]
# ### Function that generates an URL that searches a given keyword

# %%
def get_url(search_keyword):
    '''
    Generates an Amazon URL that performs search of the given keyword.
    Arguments:
        search_keyword: name of the item to be searched
    Returns:
        URL with search keyword
    '''
    
    template = 'https://www.amazon.com/s?k={}' # amazon url w/ search query placeholder
    search_keyword = search_keyword.replace(' ', '+')
    
    url = template.format(search_keyword) # adding the search keyword to the search query
    
    url += '&page={}' # adding page query placeholder
    
    return url

# %% [markdown]
# ### Function that extracts data of a single product record

# %%
def extract_record(item):
    '''
    Extracts data from an Amazon product listing from a search result.
    Arguments:
        item: product listing
    Returns:
        Tuple containing the product listing details: description, price, 
        star rating, review count, and url
    '''
    
    atag = item.h2.a # atag of the product (contains description + url of product listing)
    description = atag.text.strip() # product description
    url = 'https://www.amazon.com' + atag.get('href') # product listing url
    
    try:
        price_parent = item.find('span', 'a-price') # price parent span
        price = price_parent.find('span', 'a-offscreen').text # price value
        
    except AttributeError:
        return # if the item has no price, don't include it
    
    try:
        star_rating = item.i.text # star rating: 'x out of 5 stars'
        #star_rating = star_rating.split()[0] # keeps the numerical value only

        review_count = item.find('span', 'a-size-base s-underline-text').text # number of reviews
        
    except AttributeError:
        star_rating = np.nan
        review_count = np.nan

    result = (description, price, star_rating, review_count, url)
    
    return result

# %% [markdown]
# ### Function that extracts data of all the available product records

# %%
def extract_all_records(search_keyword):
    '''
    Extracts data from all the available Amazon product listings from a search result
    and saves it to a csv file.
    Arguments:
        search_keyword: name of the item to be searched
    '''
    
    driver = webdriver.Chrome() # starting up the webdriver
    
    url = get_url(search_keyword)
    
    records = []
    
    for page in range(1, 21):
        driver.get(url.format(page))
        scraper = BeautifulSoup(driver.page_source, 'html.parser') # BeautifulSoup object
        results = scraper.find_all('div', {'data-component-type' : 's-search-result'})
    
        for item in results:
            record = extract_record(item)
            if record:
                records.append(record)
                
    driver.close() # closing the webdriver
    
    # saving the data to a csv file
    path = 'C:/Users/sert2/Documents/Data Science/amazon-product-scraping/results.csv'
    with open(path, 'w', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['description', 'price', 'star_rating', 'review_count', 'url'])
        writer.writerows(records)

# %% [markdown]
# ## Running the scraper

# %%
extract_all_records('mechanical keyboard')

# %% [markdown]
# ## Analyzing the data

# %% [markdown]
# To analyze the data, first I'll load the csv file into a pandas dataframe:

# %%
df = pd.read_csv('results.csv', thousands=',')

# %% [markdown]
# Dimensions of the dataframe: (412 rows and 5 columns)

# %%
df.shape
# Out:
# (412, 5)

# %% [markdown]
# Taking a look at the dataframe:

# %%
df.head(5)
# Out:
#                                          description    price  \
# 0  JJTechGiant Touchscreen Gaming Mechanical Keyb...  $330.65
# 1  Mechanical Gaming Keyboard,RGB 104 Keys Ultra-...   $32.99
# 2  Mechanical Gaming Keyboard,RGB 104 Keys Ultra-...   $32.99
# 3  Portable 60% Mechanical Gaming Keyboard, MageG...   $29.99
# 4  Mechanical Keyboard RGB 104 Keys LED Backlit W...   $31.99
#
#           star_rating  review_count  \
# 0  4.4 out of 5 stars           9.0
# 1  4.6 out of 5 stars         291.0
# 2  4.6 out of 5 stars         291.0
# 3  4.4 out of 5 stars        2005.0
# 4  4.3 out of 5 stars          27.0
#
#                                                  url
# 0  https://www.amazon.com/gp/slredirect/picassoRe...
# 1  https://www.amazon.com/gp/slredirect/picassoRe...
# 2  https://www.amazon.com/Mechanical-Keyboard-Ult...
# 3  https://www.amazon.com/Portable-Mechanical-Key...
# 4  https://www.amazon.com/Mechanical-Customizable...

# %% [markdown]
# ### Cleaning

# %%
df.dtypes
# Out:
# description      object
# price            object
# star_rating      object
# review_count    float64
# url              object
# dtype: object

# %% [markdown]
# Formatting and converting `price`, `star_rating`, and `review_count` into numerical values:

# %% [markdown]
# * `price`:

# %%
df['price'] = df['price'].str.lstrip('$') # removing the '$' sign

# %%
df['price'] = pd.to_numeric(df['price']) # converting to numeric type

# %% [markdown]
# * `star_rating`:

# %%
df['star_rating'] = df['star_rating'].str.split().str[0] # keeping the first part of the string only

# %%
df['star_rating'] = pd.to_numeric(df['star_rating']) # converting to numeric type

# %% [markdown]
# * `review_count`:

# %%
df['review_count'] = pd.to_numeric(df['review_count']) # converting to numeric type

# %% [markdown]
# Current data types:

# %%
df.dtypes
# Out:
# description      object
# price           float64
# star_rating     float64
# review_count    float64
# url              object
# dtype: object

# %% [markdown]
# ### Exploring and Visualizing

# %% [markdown]
# Viewing some basic statistical details:

# %%
df.describe()
# Out:
#             price  star_rating  review_count
# count  412.000000   395.000000    395.000000
# mean    62.885752     4.491646   1441.724051
# std     45.309689     0.208466   4059.326107
# min     12.990000     3.500000      1.000000
# 25%     32.900000     4.400000     53.000000
# 50%     49.990000     4.500000    207.000000
# 75%     79.990000     4.600000   1031.500000
# max    330.650000     5.000000  42631.000000

# %% [markdown]
# * What is the average price of the product?
# * What is the best performing listing?
# * Price vs star rating
# * Price distribution

# %%
df[df['star_rating'] == df['star_rating'].max()]
# Out:
#                                            description   price  star_rating  \
# 51   JIDOHUN KB-113 Mechanical Gaming Keyboard, Wir...   27.99          5.0
# 159  Wireless Typewriter Keyboard Mechanical TKL, 2...   79.99          5.0
# 178  i-rocks K73M Mechanical Gaming Keyboard with M...   94.90          5.0
# 181  Typewriter Style Mechanical Keyboard 87 Key Re...   29.99          5.0
# 260  Newmen GM1000 96% Mechanical Gaming Keyboard W...   69.99          5.0
# 271  60% Mechanical Gaming Keyboard, 68 Keys Hot-Sw...   39.99          5.0
# 274  Newmen GM335 Hot Swappable Mechanical Keyboard...   55.99          5.0
# 306  Newmen GM1000 96% Mechanical Gaming Keyboard W...   59.99          5.0
# 339  WIZMAX, Keyboard WK2 Professional Wired Mechan...  130.99          5.0
# 393  Erasem EK1001-SL Silent Mechanical Keyboard (S...   79.99          5.0
# 407  Akko Hot Swappable Mechanical Keyboard, 5108S ...  104.98          5.0
#
#      review_count                                                url
# 51            3.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 159           1.0  https://www.amazon.com/Wireless-Typewriter-Key...
# 178           1.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 181          11.0  https://www.amazon.com/Typewriter-Mechanical-K...
# 260           6.0  https://www.amazon.com/Newmen-Mechanical-Keybo...
# 271          13.0  https://www.amazon.com/Mechanical-Keyboard-Hot...
# 274           2.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 306           6.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 339           2.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 393           3.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 407           8.0  https://www.amazon.com/Akko-Swappable-Mechanic...

# %%
df[df['star_rating'] == df['star_rating'].min()]
# Out:
#                                            description  price  star_rating  \
# 166  i-rocks K72MN Artisan Mechanical Keyboard - 10...   79.9          3.5
#
#      review_count                                                url
# 166           6.0  https://www.amazon.com/gp/slredirect/picassoRe...

# %%
df[df['review_count'] == df['review_count'].max()]
# Out:
#                                            description  price  star_rating  \
# 132  Redragon S101 Wired Gaming Keyboard and Mouse ...  46.99          4.6
#
#      review_count                                                url
# 132       42631.0  https://www.amazon.com/Redragon-S101-Keyboard-...

# %%
df[df['review_count'] > df['review_count'].quantile(.95)]
# Out:
#                                            description   price  star_rating  \
# 5    SteelSeries Apex 5 Hybrid Mechanical Gaming Ke...   79.99          4.7
# 6    Redragon K552 Mechanical Gaming Keyboard RGB L...   38.99          4.5
# 14   havit Mechanical Keyboard and Mouse Combo RGB ...   59.99          4.5
# 31   Logitech G915 Wireless Mechanical Gaming Keybo...  212.99          4.6
# 35   RK ROYAL KLUDGE RK61 Wired 60% Mechanical Gami...   56.99          4.6
# 41   Gaming Keyboard and Mouse Combo, K1 LED Rainbo...   32.99          4.6
# 43   RK ROYAL KLUDGE RK61 Wireless 60% Triple Mode ...   52.99          4.5
# 53   RK ROYAL KLUDGE RK61 2.4Ghz Wireless/Bluetooth...   54.99          4.5
# 54   Redragon K552 Mechanical Gaming Keyboard RGB L...   33.99          4.7
# 69   Corsair K70 RGB PRO Wired Mechanical Gaming Ke...  169.99          4.7
# 73   Gaming Keyboard and Mouse Combo, K1 LED Rainbo...   29.99          4.6
# 75   Razer Huntsman Mini 60% Gaming Keyboard: Fast ...   79.99          4.7
# 132  Redragon S101 Wired Gaming Keyboard and Mouse ...   46.99          4.6
# 140  HK GAMING GK61 Mechanical Gaming Keyboard - 61...   79.99          4.6
# 148  Arteck 2.4G Wireless Keyboard Stainless Steel ...   27.99          4.5
# 187  havit Mechanical Keyboard and Mouse Combo RGB ...   59.99          4.5
# 291  NPET K10 Gaming Keyboard USB Wired Floating Ke...   19.99          4.5
# 297  NPET K10 Gaming Keyboard USB Wired Floating Ke...   19.99          4.5
# 303  havit Gaming Keyboard and Mouse Combo, Backlit...   37.99          4.4
# 359  Wireless Keyboard, Arteck 2.4G Wireless Touch ...   21.30          4.2
#
#      review_count                                                url
# 5          8491.0  https://www.amazon.com/SteelSeries-Apex-Hybrid...
# 6         37080.0  https://www.amazon.com/Redragon-K552-Mechanica...
# 14        11067.0  https://www.amazon.com/Mechanical-Keyboard-Key...
# 31         8564.0  https://www.amazon.com/Logitech-Wireless-Mecha...
# 35        10890.0  https://www.amazon.com/RK-ROYAL-KLUDGE-Mechani...
# 41        11709.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 43         9877.0  https://www.amazon.com/RK-ROYAL-KLUDGE-Ultra-C...
# 53         7790.0  https://www.amazon.com/Mechanical-Keyboard-Wir...
# 54        14036.0  https://www.amazon.com/Redragon-K552-RGB-Mecha...
# 69         9428.0  https://www.amazon.com/Corsair-Mechanical-Gami...
# 73        11709.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 75        10372.0  https://www.amazon.com/Razer-Huntsman-Mini-Gam...
# 132       42631.0  https://www.amazon.com/Redragon-S101-Keyboard-...
# 140       13170.0  https://www.amazon.com/GK61-Mechanical-Gaming-...
# 148       25045.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 187       11067.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 291       16620.0  https://www.amazon.com/NPET-Floating-Keyboard-...
# 297       16620.0  https://www.amazon.com/NPET-Floating-Keyboard-...
# 303       27113.0  https://www.amazon.com/HAVIT-Rainbow-Backlit-G...
# 359        7352.0  https://www.amazon.com/gp/slredirect/picassoRe...

# %%
df.sort_values(by=['star_rating'], ascending=False).head(20)
# Out:
#                                            description   price  star_rating  \
# 181  Typewriter Style Mechanical Keyboard 87 Key Re...   29.99          5.0
# 260  Newmen GM1000 96% Mechanical Gaming Keyboard W...   69.99          5.0
# 159  Wireless Typewriter Keyboard Mechanical TKL, 2...   79.99          5.0
# 51   JIDOHUN KB-113 Mechanical Gaming Keyboard, Wir...   27.99          5.0
# 393  Erasem EK1001-SL Silent Mechanical Keyboard (S...   79.99          5.0
# 339  WIZMAX, Keyboard WK2 Professional Wired Mechan...  130.99          5.0
# 306  Newmen GM1000 96% Mechanical Gaming Keyboard W...   59.99          5.0
# 178  i-rocks K73M Mechanical Gaming Keyboard with M...   94.90          5.0
# 271  60% Mechanical Gaming Keyboard, 68 Keys Hot-Sw...   39.99          5.0
# 407  Akko Hot Swappable Mechanical Keyboard, 5108S ...  104.98          5.0
# 274  Newmen GM335 Hot Swappable Mechanical Keyboard...   55.99          5.0
# 233  YUNZII Royalaxe Y68 65% Hot Swappable Wireless...   99.00          4.9
# 228  YUNZII Royalaxe Y68 65% Hot Swappable Wireless...   99.00          4.9
# 312  Mechanical Keyboard 60%, Wired Gaming Keyboard...   13.99          4.9
# 156  Wireless Keyboard and Mouse Combo, Colorful Er...   39.99          4.8
# 46   SteelSeries New Apex Pro TKL Wireless 2023 Ed....  294.98          4.8
# 323  Updated 2022 Version “Greyhound” PC Gaming Mec...   19.99          4.8
# 153  YUNZII X75 82 Key Hot Swappable Mechanical Key...   79.99          4.8
# 25   Redragon Mechanical Gaming Keyboard, Hotswap M...   42.99          4.8
# 196  MSI Vigor GK50 Low Profile RGB Mechanical Gami...  110.00          4.8
#
#      review_count                                                url
# 181          11.0  https://www.amazon.com/Typewriter-Mechanical-K...
# 260           6.0  https://www.amazon.com/Newmen-Mechanical-Keybo...
# 159           1.0  https://www.amazon.com/Wireless-Typewriter-Key...
# 51            3.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 393           3.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 339           2.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 306           6.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 178           1.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 271          13.0  https://www.amazon.com/Mechanical-Keyboard-Hot...
# 407           8.0  https://www.amazon.com/Akko-Swappable-Mechanic...
# 274           2.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 233          10.0  https://www.amazon.com/YUNZII-Royalaxe-Swappab...
# 228          10.0  https://www.amazon.com/YUNZII-Royalaxe-Swappab...
# 312           9.0  https://www.amazon.com/Mechanical-Keyboard-Res...
# 156          40.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 46         3492.0  https://www.amazon.com/SteelSeries-New-Apex-Wi...
# 323          11.0  https://www.amazon.com/Updated-Greyhound-Mecha...
# 153          51.0  https://www.amazon.com/YUNZII-Swappable-Mechan...
# 25           25.0  https://www.amazon.com/Redragon-Programmable-A...
# 196         402.0  https://www.amazon.com/MSI-Low-Profile-Vigor-G...

# %%
df.sort_values(by=['review_count'], ascending=False).head(30)
# Out:
#                                            description   price  star_rating  \
# 132  Redragon S101 Wired Gaming Keyboard and Mouse ...   46.99          4.6
# 6    Redragon K552 Mechanical Gaming Keyboard RGB L...   38.99          4.5
# 303  havit Gaming Keyboard and Mouse Combo, Backlit...   37.99          4.4
# 148  Arteck 2.4G Wireless Keyboard Stainless Steel ...   27.99          4.5
# 297  NPET K10 Gaming Keyboard USB Wired Floating Ke...   19.99          4.5
# 291  NPET K10 Gaming Keyboard USB Wired Floating Ke...   19.99          4.5
# 54   Redragon K552 Mechanical Gaming Keyboard RGB L...   33.99          4.7
# 140  HK GAMING GK61 Mechanical Gaming Keyboard - 61...   79.99          4.6
# 73   Gaming Keyboard and Mouse Combo, K1 LED Rainbo...   29.99          4.6
# 41   Gaming Keyboard and Mouse Combo, K1 LED Rainbo...   32.99          4.6
# 14   havit Mechanical Keyboard and Mouse Combo RGB ...   59.99          4.5
# 187  havit Mechanical Keyboard and Mouse Combo RGB ...   59.99          4.5
# 35   RK ROYAL KLUDGE RK61 Wired 60% Mechanical Gami...   56.99          4.6
# 75   Razer Huntsman Mini 60% Gaming Keyboard: Fast ...   79.99          4.7
# 43   RK ROYAL KLUDGE RK61 Wireless 60% Triple Mode ...   52.99          4.5
# 69   Corsair K70 RGB PRO Wired Mechanical Gaming Ke...  169.99          4.7
# 31   Logitech G915 Wireless Mechanical Gaming Keybo...  212.99          4.6
# 5    SteelSeries Apex 5 Hybrid Mechanical Gaming Ke...   79.99          4.7
# 53   RK ROYAL KLUDGE RK61 2.4Ghz Wireless/Bluetooth...   54.99          4.5
# 359  Wireless Keyboard, Arteck 2.4G Wireless Touch ...   21.30          4.2
# 170  Redragon K585 DITI One-Handed RGB Mechanical G...   44.99          4.4
# 18   Redragon K556 RGB LED Backlit Wired Mechanical...   59.99          4.6
# 119  EPOMAKER SKYLOONG SK61 61 Keys 60% Hot Swappab...   52.99          4.6
# 211  DIERYA DK63N 60% Wireless Wired Mechanical Gam...   37.99          4.4
# 70   Snpurdiri 60% Wired Gaming Keyboard, RGB Backl...   28.99          4.3
# 17   RK ROYAL KLUDGE Typewriter Style Mechanical Ga...   66.99          4.6
# 389  Razer BlackWidow TE Chroma v2 TKL Tenkeyless M...  116.23          4.5
# 248  Redragon K530 Pro Draconic 60% Wireless RGB Me...   54.99          4.5
# 371  Redragon K582 SURARA RGB LED Backlit Mechanica...   44.99          4.5
# 12   Redragon K582 SURARA RGB LED Backlit Mechanica...   44.99          4.5
#
#      review_count                                                url
# 132       42631.0  https://www.amazon.com/Redragon-S101-Keyboard-...
# 6         37080.0  https://www.amazon.com/Redragon-K552-Mechanica...
# 303       27113.0  https://www.amazon.com/HAVIT-Rainbow-Backlit-G...
# 148       25045.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 297       16620.0  https://www.amazon.com/NPET-Floating-Keyboard-...
# 291       16620.0  https://www.amazon.com/NPET-Floating-Keyboard-...
# 54        14036.0  https://www.amazon.com/Redragon-K552-RGB-Mecha...
# 140       13170.0  https://www.amazon.com/GK61-Mechanical-Gaming-...
# 73        11709.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 41        11709.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 14        11067.0  https://www.amazon.com/Mechanical-Keyboard-Key...
# 187       11067.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 35        10890.0  https://www.amazon.com/RK-ROYAL-KLUDGE-Mechani...
# 75        10372.0  https://www.amazon.com/Razer-Huntsman-Mini-Gam...
# 43         9877.0  https://www.amazon.com/RK-ROYAL-KLUDGE-Ultra-C...
# 69         9428.0  https://www.amazon.com/Corsair-Mechanical-Gami...
# 31         8564.0  https://www.amazon.com/Logitech-Wireless-Mecha...
# 5          8491.0  https://www.amazon.com/SteelSeries-Apex-Hybrid...
# 53         7790.0  https://www.amazon.com/Mechanical-Keyboard-Wir...
# 359        7352.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 170        7115.0  https://www.amazon.com/Redragon-One-Handed-Mec...
# 18         6954.0  https://www.amazon.com/Redragon-K556-Mechanica...
# 119        6415.0  https://www.amazon.com/EPOMAKER-SKYLOONG-Swapp...
# 211        5910.0  https://www.amazon.com/DIERYA-DK63N-Mechanical...
# 70         4896.0  https://www.amazon.com/Snpurdiri-Keyboard-Ultr...
# 17         4720.0  https://www.amazon.com/RK-ROYAL-KLUDGE-Typewri...
# 389        4512.0  https://www.amazon.com/Razer-BlackWidow-Tourna...
# 248        4506.0  https://www.amazon.com/Redragon-Draconic-Wirel...
# 371        4212.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 12         4212.0  https://www.amazon.com/Redragon-Mechanical-Key...

# %%
df[df['star_rating'] >= 4.5].sort_values(by=['review_count'], ascending=False).head(30)
# Out:
#                                            description   price  star_rating  \
# 132  Redragon S101 Wired Gaming Keyboard and Mouse ...   46.99          4.6
# 6    Redragon K552 Mechanical Gaming Keyboard RGB L...   38.99          4.5
# 148  Arteck 2.4G Wireless Keyboard Stainless Steel ...   27.99          4.5
# 297  NPET K10 Gaming Keyboard USB Wired Floating Ke...   19.99          4.5
# 291  NPET K10 Gaming Keyboard USB Wired Floating Ke...   19.99          4.5
# 54   Redragon K552 Mechanical Gaming Keyboard RGB L...   33.99          4.7
# 140  HK GAMING GK61 Mechanical Gaming Keyboard - 61...   79.99          4.6
# 73   Gaming Keyboard and Mouse Combo, K1 LED Rainbo...   29.99          4.6
# 41   Gaming Keyboard and Mouse Combo, K1 LED Rainbo...   32.99          4.6
# 14   havit Mechanical Keyboard and Mouse Combo RGB ...   59.99          4.5
# 187  havit Mechanical Keyboard and Mouse Combo RGB ...   59.99          4.5
# 35   RK ROYAL KLUDGE RK61 Wired 60% Mechanical Gami...   56.99          4.6
# 75   Razer Huntsman Mini 60% Gaming Keyboard: Fast ...   79.99          4.7
# 43   RK ROYAL KLUDGE RK61 Wireless 60% Triple Mode ...   52.99          4.5
# 69   Corsair K70 RGB PRO Wired Mechanical Gaming Ke...  169.99          4.7
# 31   Logitech G915 Wireless Mechanical Gaming Keybo...  212.99          4.6
# 5    SteelSeries Apex 5 Hybrid Mechanical Gaming Ke...   79.99          4.7
# 53   RK ROYAL KLUDGE RK61 2.4Ghz Wireless/Bluetooth...   54.99          4.5
# 18   Redragon K556 RGB LED Backlit Wired Mechanical...   59.99          4.6
# 119  EPOMAKER SKYLOONG SK61 61 Keys 60% Hot Swappab...   52.99          4.6
# 17   RK ROYAL KLUDGE Typewriter Style Mechanical Ga...   66.99          4.6
# 389  Razer BlackWidow TE Chroma v2 TKL Tenkeyless M...  116.23          4.5
# 248  Redragon K530 Pro Draconic 60% Wireless RGB Me...   54.99          4.5
# 12   Redragon K582 SURARA RGB LED Backlit Mechanica...   44.99          4.5
# 371  Redragon K582 SURARA RGB LED Backlit Mechanica...   44.99          4.5
# 341  MOTOSPEED 2.4GHz Wireless/Wired Mechanical Gam...   32.99          4.6
# 46   SteelSeries New Apex Pro TKL Wireless 2023 Ed....  294.98          4.8
# 247  Redragon K580 VATA RGB LED Backlit Mechanical ...   69.99          4.7
# 94   Logitech G910 Orion Spectrum RGB Wired Mechani...  129.98          4.6
# 237  Razer BlackWidow V3 Mechanical Gaming Keyboard...  139.99          4.7
#
#      review_count                                                url
# 132       42631.0  https://www.amazon.com/Redragon-S101-Keyboard-...
# 6         37080.0  https://www.amazon.com/Redragon-K552-Mechanica...
# 148       25045.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 297       16620.0  https://www.amazon.com/NPET-Floating-Keyboard-...
# 291       16620.0  https://www.amazon.com/NPET-Floating-Keyboard-...
# 54        14036.0  https://www.amazon.com/Redragon-K552-RGB-Mecha...
# 140       13170.0  https://www.amazon.com/GK61-Mechanical-Gaming-...
# 73        11709.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 41        11709.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 14        11067.0  https://www.amazon.com/Mechanical-Keyboard-Key...
# 187       11067.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 35        10890.0  https://www.amazon.com/RK-ROYAL-KLUDGE-Mechani...
# 75        10372.0  https://www.amazon.com/Razer-Huntsman-Mini-Gam...
# 43         9877.0  https://www.amazon.com/RK-ROYAL-KLUDGE-Ultra-C...
# 69         9428.0  https://www.amazon.com/Corsair-Mechanical-Gami...
# 31         8564.0  https://www.amazon.com/Logitech-Wireless-Mecha...
# 5          8491.0  https://www.amazon.com/SteelSeries-Apex-Hybrid...
# 53         7790.0  https://www.amazon.com/Mechanical-Keyboard-Wir...
# 18         6954.0  https://www.amazon.com/Redragon-K556-Mechanica...
# 119        6415.0  https://www.amazon.com/EPOMAKER-SKYLOONG-Swapp...
# 17         4720.0  https://www.amazon.com/RK-ROYAL-KLUDGE-Typewri...
# 389        4512.0  https://www.amazon.com/Razer-BlackWidow-Tourna...
# 248        4506.0  https://www.amazon.com/Redragon-Draconic-Wirel...
# 12         4212.0  https://www.amazon.com/Redragon-Mechanical-Key...
# 371        4212.0  https://www.amazon.com/gp/slredirect/picassoRe...
# 341        4083.0  https://www.amazon.com/MOTOSPEED-Wireless-Mech...
# 46         3492.0  https://www.amazon.com/SteelSeries-New-Apex-Wi...
# 247        3403.0  https://www.amazon.com/Redragon-K580-PRO-Mecha...
# 94         3403.0  https://www.amazon.com/Logitech-Spectrum-Mecha...
# 237        3297.0  https://www.amazon.com/Razer-BlackWidow-Mechan...
